# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Vérifie que chaque paire successive dans P correspond bien à une arête dans G.
#
# Vérifie que chaque sommet apparaît exactement une fois.
#
# Vérifie que le premier sommet = s et le dernier = t.
#
#
#
#
# .

# %% [markdown]
# Vérifier les arêtes :
#
# Pour chaque paire de sommets consécutifs
# (vi,vi+1)
# (v
# i
# 	​
#
# ,v
# i+1
# 	​
#
# ) dans le chemin candidat
# P
# P, on vérifie si une arête existe dans
# G
# G.
#
# Il y a au plus
# n−1
# n−1 arêtes à vérifier.
#
# Chaque vérification est supposée O(1) (accès constant).
# 👉 Complexité : O(n)

# %% [markdown]
# 2.Vérifier que chaque sommet est unique :
#
# On parcourt
# P
# P et on enregistre chaque sommet dans une table de hachage / dictionnaire (ou un tableau booléen “visited”).
#
# Si un sommet apparaît deux fois, ce n’est pas un chemin valide.
# 👉 Complexité : O(n)
#
# 3.Vérifier les sommets de début et de fin :
#
# On compare
# v1
# v
# 1
# 	​
#
#  avec
# s
# s et
# vn
# v
# n
# 	​
#
#  avec
# t
# t.
# 👉 Complexité : O(1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Étape 2 — Réduction polynomiale : HC → HP

# %% [markdown]
# Tu pars d’un graphe G (instance de HC).
# Tu construis un nouveau graphe G’ (instance de HP) comme ceci :
#
# Choisis un sommet v dans G (au hasard).
#
# Ajoute un nouveau sommet s.
#
# Relie s à tous les voisins de v.
#
# Définis les deux sommets particuliers du HP :
#
# s (le nouveau sommet)
#
# v (l’ancien sommet choisi dans G)

# %% [markdown]
# Étape 3 — Démonstration logique complète
#
# On sait : HC est NP-complet.
#
# On vient de montrer : HC ≤P HP (réduction polynomiale).
#
# HP est dans NP (vérifiable rapidement).
#
# Donc :
#
# ✅ Hamiltonian Path est NP-complet.
