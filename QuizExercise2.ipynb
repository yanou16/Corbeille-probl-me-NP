# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Date :A graph
# G=(V,E)
#
# question: Is there a Hamiltonian Cycle in ?

# %% [markdown]
# Un graphe
# G=(V,E), deux sommets
#
# s et
#
# t, une fonction de poids
#
# w(e), et un entier
# k

# %% [markdown]
# Existe-t-il dans G un chemin de s à  t
#  dont la longueur totale est inférieure à k ?
