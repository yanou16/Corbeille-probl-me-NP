# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Write down the optimization problem :
#
# Data: a graph G
#
#
# Question: What is the minimum number of colors needed to color G?

# %% [markdown]
# Problème de décision associé :
#
# Data: a graph G and an integer k
#
# Question: Can G be colored using at most k colors?
